# %%
# %sql
SELECT * FROM workspace.silver.crm_products
LIMIT 10;

# %%
# %sql
SELECT DISTINCT product_line FROM workspace.silver.crm_products

# %%
# %sql
SELECT COUNT(product_line) AS count_pl
FROM workspace.silver.crm_products
WHERE product_line == "R"

# %%
# %sql
SELECT
    product_line,
    COUNT(*) AS count_pl
FROM workspace.silver.crm_products
GROUP BY product_line;

# %%
# %sql
SELECT

    COUNT(product_line) AS count_pl
FROM workspace.silver.crm_products

# %% [markdown]
# # check empty space in bronze

# %%
# %sql
select
  count(*) as rows_with_spaces
from workspace.bronze.crm_prd_info
where prd_key is not null
  and prd_key <> trim(prd_key);

# %% [markdown]
# # check empty space in silver

# %%
# %sql
select
  count(*) as rows_with_spaces
from workspace.silver.crm_customers
where first_name is not null
  and first_name != trim(first_name); -- <> same as !=

# %%
# %sql
select count(prd_key)
from workspace.bronze.crm_prd_info;
