# %% [markdown]
# # Import libraries and modules

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import trim, col
from pyspark.sql.types import StringType
from pyspark.sql.window import Window
from delta.tables import DeltaTable

import logging

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logger = logging.getLogger("silver_crm_cust_info")
logger.setLevel(logging.INFO)

# %% [markdown]
# # Rename map

# %%
RENAME_MAP = {
    'sls_ord_num': 'order_number',
    'sls_prd_key': 'product_key',
    'sls_cust_id': 'customer_id',
    'sls_order_dt': 'order_date',
    'sls_ship_dt': 'ship_date',
    'sls_due_dt': 'due_date',
    'sls_quantity': 'quantity',
    'sls_price': 'price'
    }

# %% [markdown]
# # Reading data from the Bronze and check schema

# %%
df = spark.table("workspace.bronze.crm_sales_details")
df.printSchema()
df = df.drop("sls_sales")

# %% [markdown]
# #Renaming columns

# %%
def rename_columns(df, RENAME_MAP:dict):
    for old_name, new_name in RENAME_MAP.items():
        df = df.withColumnRenamed(old_name, new_name)
    return df
df = rename_columns(df, RENAME_MAP)
df.printSchema()

# %% [markdown]
# # Trim strings columns

# %%
def trim_string_columns(df):
    for field in df.schema.fields:
        if isinstance(field.dataType, StringType):
            df = df.withColumn(field.name, trim(col(field.name)))
    return df
df = trim_string_columns(df)
df.display()
#df.printSchema()

# %% [markdown]
# # Convert numeric string to date type.

# %%
def convert_to_date(df, cols):
    
    for c in cols:
        df = df.withColumn(
            c,
            F.to_date(F.col(c), "yyyyMMdd")
        )
        
    return df

    date_cols = ["order_date", "ship_date", "due_date"]

df = convert_to_date(df, date_cols)
df.printSchema()

# %% [markdown]
# # # Convert numeric string to "int" data type.

# %%
def convert_to_int(df, cols):
    for c in cols:
        df = df.withColumn(c,
                           F.col(c).cast("int")
                           )
    return df
cols = ["quantity"]

df = convert_to_int(df, cols)
df.printSchema()


df.filter(~F.col("quantity").rlike("^[0-9]+$")).show() # check for non-numeric values

# %% [markdown]
# # %md
# # # Convert numeric string to "decimal" data type.

# %%
def convert_to_decimal(df, cols):
    for c in cols:
        df = df.withColumn(c,
                           F.col(c).cast("decimal(10,2)")
                           )
    return df

    
cols = ["price"]

df = convert_to_decimal(df, cols)
df.printSchema()

# %% [markdown]
# # Write to silver

# %%
def write_to_silver(df, target_table, business_keys):

    spark = df.sparkSession

    if not spark.catalog.tableExists(target_table):

        logger.info("Target table does not exist. Creating new table.")

        (
            df.write
            .format("delta")
            .mode("overwrite")
            .saveAsTable(target_table)
        )

        return

    delta_table = DeltaTable.forName(spark, target_table)

    logger.info("Executing MERGE (incremental upsert)")

    merge_condition = " AND ".join(
        [f"target.{c} = source.{c}" for c in business_keys]
    )

    (
        delta_table.alias("target")
        .merge(
            df.alias("source"),
            merge_condition
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

    logger.info("MERGE completed successfully")

# %%
# %sql
SELECT *
FROM workspace.silver.crm_sales_details;

# %% [markdown]
# #check NULL and empty string together in one condition

# %%
df.select(
    F.sum(
        (F.col("quantity").isNull() | (F.col("quantity") == ""))
        .cast("int")
    ).alias("quantity_missing")
).show()

# %%
rows_before = df.count()
print("Rows before:", rows_before)

# %%
df = df.withColumn(
    "quantity",
    F.col("quantity").cast("int")
)
df.printSchema()

# %%
rows_after = df.count()
print("Rows after:", rows_after)

# %%
df.select(
    F.sum(
        (F.col("quantity").isNull())
        .cast("int")
    ).alias("quantity_missing")
).show()

# %% [markdown]
# # Check nulls values

# %%
cols = ["order_number", "product_key", "customer_id", "order_date", "ship_date", "due_date", "total_sales", "quantity", "price"]

checks = []

for c in cols:
    checks.append(
            F.sum                      # count nulls 
            (F.col(c).isNull()         # check nulls
            .cast("int"))              # before we count we need to transform to int
            .alias(f"{c}_nulls")       # name of the column + alias _nulls
            )

    
df.select(*checks).show()

# %% [markdown]
# #Compare the counts

# %% [markdown]
# ## Check empty string

# %%
price_missing = df.filter(
    F.col("price") == ""
).count()

sales_missing = df.filter(
    F.col("total_sales") == ""
).count()

print("Missing price:", price_missing)
print("Missing total_sales:", sales_missing)

# %% [markdown]
# ## Check nulls

# %%
price_missing = df.filter(
    F.col("price").isNull() | (F.trim(F.col("price")) == "")
).count()

sales_missing = df.filter(
    F.col("total_sales").isNull() | (F.trim(F.col("total_sales")) == "")
).count()

print("Missing price:", price_missing)
print("Missing total_sales:", sales_missing)

# %%
df.filter(
    F.col("price").isNull() & 
    F.col("total_sales").isNotNull()
).select(
    "order_number",
    "product_key",
    "quantity",
    "price",
    "total_sales"
).show(20, False)

# %%
df.filter(
    F.col("total_sales").isNull() & 
    F.col("price").isNotNull()
).select(
    "order_number",
    "product_key",
    "quantity",
    "price"
).show(20, False)

# %%
df.filter(
    F.col("total_sales").isNull() &
    F.col("price").isNotNull()
).select(
    "order_number",
    "product_key",
    "customer_id",
    "quantity",
    "price",
    #"total_sales"
).show(20, False)

# %%
df.filter(
    F.col("quantity")==2
    ).select(
    "order_number",
    "product_key",
    "customer_id",
    "quantity",
    "price",
    #"total_sales"
).show(20, False)

# %% [markdown]
# ## Test if price and total_sales are always equal

# %%
df.filter(
    F.col("price") != F.col("total_sales")
).select(
    "order_number",
    "quantity",
    "price",
    #"total_sales"
).show(20, False)

# %% [markdown]
# ## classify mismatches

# %%
df.groupBy("order_number", "product_key") \
  .count() \
  .filter("count > 1") \
  .show(500)

# %% [markdown]
# # Check Ingestion/times

# %%
df.select("ingest_timestamp") \
  .distinct() \
  .orderBy("ingest_timestamp") \
  .show(20, False)

# %% [markdown]
# # CHECK. We want to understand how bad the data is before fixing.
# ## This code loops through date columns, counts nulls, zeros, and wrong-length values.
# ## Then shows all those counts in one row to spot data problems.

# %%
date_cols = ["order_date", "ship_date", "due_date"]

checks = []

for c in date_cols:
    checks.append(
        F.sum
            (F
            .col(c).isNull()
            .cast("int")) # before we count we need to transform to int
            .alias(f"{c}_nulls") # name of the column + alias _nulls
            )

result = df.select(*checks) # * unpacking the list of columns

display(result)

# %% [markdown]
# # Write to Silver Table

# %%
(
    df.write
    .mode("overwrite")
    .format("delta")
    .option("overwriteSchema", "true") 
    .saveAsTable("silver.crm_sales_details")
)

# %%
# %sql
SELECT
  COUNT(*) AS total_rows,
  SUM(CASE WHEN order_date IS NOT NULL THEN 1 ELSE 0 END) AS valid_dates,
  SUM(CASE WHEN order_date IS NULL THEN 1 ELSE 0 END) AS null_dates
FROM workspace.silver.crm_sales_details;

# %%
# %sql
SELECT *
FROM workspace.silver.crm_sales_details
WHERE customer_id IS NULL;
