# %% [markdown]
# # Import libraries and modules

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import trim, col
from pyspark.sql.types import StringType
from pyspark.sql.window import Window

# %% [markdown]
# # Rename map

# %%
RENAME_MAP = {
    'sls_ord_num': 'order_number',
    'sls_prd_key': 'product_key',
    'sls_cust_id': 'customer_id',
    'sls_order_dt': 'order_date',
    'sls_ship_dt': 'ship_date',
    'sls_due_dt': 'due_date',
    'sls_sales': 'total_sales',
    'sls_quantity': 'quantity',
    'sls_price': 'price'
    }

# %% [markdown]
# # Reading data from the Bronze and check schema

# %%
df = spark.table("workspace.bronze.crm_sales_details")
df.printSchema()

# %% [markdown]
# #Renaming columns

# %%
def rename_columns(df, RENAME_MAP:dict):
    for old_name, new_name in RENAME_MAP.items():
        df = df.withColumnRenamed(old_name, new_name)
    return df
df = rename_columns(df, RENAME_MAP)
df.printSchema()

# %%
window_spec = Window.partitionBy(
    "order_number", "product_key"
).orderBy(
    F.col("ingest_timestamp").desc()
)

df = df.withColumn(
    "row_num",
    F.row_number().over(window_spec)
)

df = df.filter(F.col("row_num") == 1)
df = df.drop("row_num")

df.groupBy("order_number", "product_key") \
  .count() \
  .filter("count > 1") \
  .show()

display(df)

# %% [markdown]
# # Trim strings columns

# %%
def trim_string_columns(df):
    for field in df.schema.fields:
        if isinstance(field.dataType, StringType):
            df = df.withColumn(field.name, trim(col(field.name)))
    return df
df = trim_string_columns(df)
df.display()
#df.printSchema()

# %% [markdown]
# # Check nulls values

# %%
cols = ["order_number", "product_key", "customer_id", "order_date", "ship_date", "due_date", "total_sales", "quantity", "price"]

checks = []

for c in cols:
    checks.append(
            F.sum                      # count nulls 
            (F.col(c).isNull()         # check nulls
            .cast("int"))              # before we count we need to transform to int
            .alias(f"{c}_nulls")       # name of the column + alias _nulls
            )

    
df.select(*checks).show()

# %% [markdown]
# #Compare the counts

# %% [markdown]
# ## Check empty string

# %%
price_missing = df.filter(
    F.col("price") == ""
).count()

sales_missing = df.filter(
    F.col("total_sales") == ""
).count()

print("Missing price:", price_missing)
print("Missing total_sales:", sales_missing)

# %% [markdown]
# ## Check nulls

# %%
price_missing = df.filter(
    F.col("price").isNull() | (F.trim(F.col("price")) == "")
).count()

sales_missing = df.filter(
    F.col("total_sales").isNull() | (F.trim(F.col("total_sales")) == "")
).count()

print("Missing price:", price_missing)
print("Missing total_sales:", sales_missing)

# %%
df.filter(
    F.col("total_sales").isNull() &
    F.col("price").isNotNull()
).select("quantity","price","total_sales").show(20, False)

# %%
df.filter(
    F.col("price").isNull() &
    F.col("total_sales").isNotNull()
).select("quantity","price","total_sales").show(20, False)

# %%
df.filter(
    F.col("price").isNull() &
    F.col("total_sales").isNotNull()
).select(
    "order_number",
    "product_key",
    "customer_id",
    "quantity",
    "price",
    "total_sales"
).show(20, False)

# %%
df.filter(
    F.col("total_sales").isNull() &
    F.col("price").isNotNull()
).select(
    "order_number",
    "product_key",
    "customer_id",
    "quantity",
    "price",
    "total_sales"
).show(20, False)

# %%
df.filter(
    F.col("quantity")==1
    ).select(
    "order_number",
    "product_key",
    "customer_id",
    "quantity",
    "price",
    "total_sales"
).show(20, False)

# %% [markdown]
# ## Test if price and total_sales are always equal

# %%
df.filter(
    F.col("price") != F.col("total_sales")
).select(
    "order_number",
    "quantity",
    "price",
    "total_sales"
).show(20, False)

# %% [markdown]
# ## classify mismatches

# %%
df.select(
    F.sum((F.col("price") == F.col("total_sales")).cast("int")).alias("equal"),
    F.sum((F.col("price") == -F.col("total_sales")).cast("int")).alias("opposite_sign"),
    F.sum((F.col("total_sales") == 0).cast("int")).alias("zero_sales"),
    F.sum((F.col("price") < 0).cast("int")).alias("negative_price"),
    F.sum((F.col("total_sales") < 0).cast("int")).alias("negative_sales")
).show()

# %%
df.groupBy("order_number", "product_key") \
  .count() \
  .filter("count > 1") \
  .show()

# %%
df.filter(
    (F.col("order_number") == "SO43697") &
    (F.col("product_key") == "BK-R93R-62")
).select(
    "product_key",
    "order_number",
    "quantity",
    "price",
    "total_sales"
).show(50)

# %%
df.groupBy("order_number", "product_key") \
  .count() \
  .filter("count > 1") \
  .show(500)

# %% [markdown]
# # Check Ingestion/times

# %%
df.select("ingest_timestamp") \
  .distinct() \
  .orderBy("ingest_timestamp") \
  .show(20, False)

# %% [markdown]
# # CHECK. We want to understand how bad the data is before fixing.
# ## This code loops through date columns, counts nulls, zeros, and wrong-length values.
# ## Then shows all those counts in one row to spot data problems.

# %%
date_cols = ["order_date", "ship_date", "due_date"]

checks = []

for c in date_cols:
    checks.append(
        F.sum
            (F
            .col(c).isNull()
            .cast("int")) # before we count we need to transform to int
            .alias(f"{c}_nulls") # name of the column + alias _nulls
            )

result = df.select(*checks) # * unpacking the list of columns

display(result)

# %% [markdown]
# # Decide the correct schema

# %%
df.select("order_number").isNull()
df.printSchema()

# %% [markdown]
# # CHECK. Use copy of df to check if data looks good after the conversion

# %%
df2 = (
    df
    .withColumn("order_date_dt",
        F.to_date(F.col("order_date").cast("string"), "yyyyMMdd")
    )
    .withColumn("ship_date_dt",
        F.to_date(F.col("ship_date").cast("string"), "yyyyMMdd")
    )
    .withColumn("due_date_dt",
        F.to_date(F.col("due_date").cast("string"), "yyyyMMdd")
    )
)
df2.display()
#df2.printSchema()

# %% [markdown]
# #Convert int to date

# %%
def convert_int_to_date(col_name: str):
    return (
        F.when(F.col(col_name).isNull() | (F.col(col_name) == 0), None)
         .when(F.length(F.col(col_name).cast("string")) == 8,
               F.to_date(F.col(col_name).cast("string"), "yyyyMMdd"))
         .otherwise(None)
    )

df.withColumn("test_date", convert_int_to_date("order_date")).show(5)

# %% [markdown]
# ## Owerite the columns

# %%
df = df.withColumn("order_date", convert_int_to_date("order_date")) \
       .withColumn("ship_date",   convert_int_to_date("ship_date")) \
       .withColumn("due_date",    convert_int_to_date("due_date"))

# %%
df.printSchema()                          # see date type
df.select("order_date", "ship_date", "due_date").show(5, truncate=False)

# %% [markdown]
# # Write to Silver Table

# %%
(
    df.write
    .mode("overwrite")
    .format("delta")
    .option("overwriteSchema", "true") 
    .saveAsTable("silver.crm_sales_details")
)

# %%
# %sql
SELECT
  COUNT(*) AS total_rows,
  SUM(CASE WHEN order_date IS NOT NULL THEN 1 ELSE 0 END) AS valid_dates,
  SUM(CASE WHEN order_date IS NULL THEN 1 ELSE 0 END) AS null_dates
FROM workspace.silver.crm_sales_details;

# %%
# %sql
SELECT *
FROM workspace.silver.crm_sales_details
WHERE customer_id IS NULL;
