# %% [markdown]
# #Import libraries/Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import trim, col
from pyspark.sql.types import StringType

# %% [markdown]
# # Mapping/Renaming Columns
# ## dictionary:  key/values

# %%
RENAME_MAP = {
    "prd_id": "product_id",
    "cat_id": "category_id",
    "prd_key": "product_number_key",
    "prd_nm": "product_name",
    "prd_cost": "product_cost",
    "prd_line": "product_line",
    "prd_start_dt": "start_date",
    "prd_end_dt": "end_date"
}

# %% [markdown]
# #Reading from Bronze

# %%
df = spark.table("workspace.bronze.crm_prd_info")

# %% [markdown]
# # Silver transformation

# %% [markdown]
# ## Check data types/schema

# %%
df.printSchema()

# %% [markdown]
# ## Trim whitespaces

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(field.name,trim(col(field.name)))

# %% [markdown]
# ## Rename columns

# %%
def rename_columns(df, RENAME_MAP: dict):
    for old_name, new_name in RENAME_MAP.items():
        df = df.withColumnRenamed(old_name, new_name)
    return df

# %%
df = rename_columns(df, RENAME_MAP)
df.printSchema()

# %% [markdown]
# # Trim all string columns

# %%
def trim_string_columns(df):
    for field in df.schema.fields:
        if isinstance(field.dataType, StringType):
            df = df.withColumn(field.name, F.trim(F.col(field.name)))
    return df

# %% [markdown]
# # Normalize/standardize values inside product_line
# ## Current values: R, S, M, T, null.  Make them clean, consistent, readable.

# %%
from pyspark.sql.functions import col, when

df = df.withColumn(
    "product_line",
    when(col("product_line") == "R", "Road")
     .when(col("product_line") == "S", "Sport")
     .when(col("product_line") == "M", "Mountain")
     .when(col("product_line") == "T", "Touring")
     .otherwise(None)
)

# %%
def is_missing_str(col_name: str):
    return F.col(col_name).isNull() | (F.trim(F.col(col_name)) == "")

# %%
exact_dups = (
    df.groupBy("product_number_key","start_date","end_date","product_cost","product_name","product_line")
      .count()
      .filter("count > 1")
)
display(exact_dups)

# %%
period_dups = (
    df.groupBy("product_number_key","start_date","end_date")
      .count()
      .filter("count > 1")
)
display(period_dups)

# %%
dups_after_df = (
    df.filter(F.col("product_number_key").isNotNull() & (F.trim(F.col("product_number_key")) != ""))
      .groupBy("product_number_key")
      .count()
      .filter(F.col("count") > 1)
      .orderBy(F.col("count").desc())
)

display(dups_after_df)

# %% [markdown]
# # Set invalid end_dates column to NULL

# %%
df = df.withColumn(
    "end_date",
    F.when(
        F.col("end_date").isNotNull() & (F.col("end_date") < F.col("start_date")),
        F.lit(None)
    ).otherwise(F.col("end_date"))
)

# %% [markdown]
# # Write into silver Table

# %%
(
    df.write
    .mode("overwrite")
    .format("delta")
    .saveAsTable("silver.crm_products")
)

# %%
# %sql
SELECT *
FROM workspace.silver.crm_products

# %% [markdown]
# # CHECK: Show INVALID rows in end_date column. Where end_date < start_date

# %%
# %sql
SELECT COUNT(*) AS bad_rows
FROM silver.crm_products
WHERE end_date IS NOT NULL 
  AND end_date < start_date;

# %%
# %sql
SELECT product_id, product_name, start_date, end_date
FROM workspace.silver.crm_products
WHERE end_date IS NOT NULL
  AND end_date < start_date
ORDER BY start_date;
